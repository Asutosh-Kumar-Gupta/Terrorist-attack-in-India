# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')

# %%
# %matplotlib inline

# %%
import seaborn as sns

# %%
dataset = pd.read_csv('C:/Users/Asutosh/Desktop/TerrorismDataIndia.csv', engine='python')

# %%
dataset.head()
# Out:
#    Unnamed: 0       eventid  iyear  imonth  iday approxdate  extended  \
# 0        1186  197202220004   1972       2    22        NaN         0
# 1        2764  197501190004   1975       1     2        NaN         0
# 2        3857  197605260001   1976       5    26        NaN         0
# 3        5327  197709280004   1977       9    28        NaN         0
# 4        7337  197901130004   1979       1    13        NaN         0
#
#   resolution  country country_txt  ...  \
# 0        NaN       92       India  ...
# 1        NaN       92       India  ...
# 2        NaN       92       India  ...
# 3        NaN       92       India  ...
# 4        NaN       92       India  ...
#
#                                             addnotes  \
# 0                                                NaN
# 1  The case is very unclear and there are many ru...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                               scite1  \
# 0                                                NaN
# 1  "Leaders of India Irate at Killing: Death of A...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                               scite2 scite3  \
# 0                                                NaN    NaN
# 1  Dhananjay Mahapatra, "SC: Why has LN Mishra mu...    NaN
# 2                                                NaN    NaN
# 3                                                NaN    NaN
# 4                                                NaN    NaN
#
#                                    dbsource  INT_LOG  INT_IDEO  INT_MISC  \
# 0                              Hijacking DB        1         1         1
# 1  UMD Encyclopedia of World Terrorism 2012        0         0         0
# 2                                      PGIS       -9        -9         0
# 3                              Hijacking DB        1         1         1
# 4                                      PGIS        0         0         0
#
#   INT_ANY related
# 0       1     NaN
# 1       0     NaN
# 2      -9     NaN
# 3       1     NaN
# 4       0     NaN
#
# [5 rows x 136 columns]

# %%
dataset.columns
# Out:
# Index(['Unnamed: 0', 'eventid', 'iyear', 'imonth', 'iday', 'approxdate',
#        'extended', 'resolution', 'country', 'country_txt',
#        ...
#        'addnotes', 'scite1', 'scite2', 'scite3', 'dbsource', 'INT_LOG',
#        'INT_IDEO', 'INT_MISC', 'INT_ANY', 'related'],
#       dtype='object', length=136)

# %%
plt.figure(figsize=(16,7))
sns.heatmap(dataset.isnull(),cmap='viridis',cbar=False)

# %%
dataset=dataset[['eventid','iyear', 'imonth', 'country_txt', 'region_txt', 'provstate', 'city', 'latitude', 'longitude', 'success', 'attacktype1_txt', 'targtype1_txt', 'natlty1_txt', 'gname', 'weaptype1_txt', 'weapsubtype1_txt', 'nkill', 'nwound']]

# %%
dataset.head()
# Out:
#         eventid  iyear  imonth country_txt  region_txt    provstate  \
# 0  197202220004   1972       2       India  South Asia        Delhi
# 1  197501190004   1975       1       India  South Asia        Bihar
# 2  197605260001   1976       5       India  South Asia        Delhi
# 3  197709280004   1977       9       India  South Asia  Maharashtra
# 4  197901130004   1979       1       India  South Asia        Assam
#
#          city   latitude  longitude  success    attacktype1_txt  \
# 0   New Delhi  28.585836  77.153336        1          Hijacking
# 1  Samastipur  25.863042  85.781004        1  Bombing/Explosion
# 2   New Delhi  28.585836  77.153336        1  Bombing/Explosion
# 3      Bombay  19.075984  72.877656        1          Hijacking
# 4     Unknown  26.200605  92.937574        1      Armed Assault
#
#           targtype1_txt natlty1_txt                    gname weaptype1_txt  \
# 0   Airports & Aircraft     Germany             Palestinians    Explosives
# 1  Government (General)       India             Ananda Marga    Explosives
# 2   Airports & Aircraft       India                  Unknown    Explosives
# 3   Airports & Aircraft       Japan  Japanese Red Army (JRA)      Firearms
# 4                Police       India              Naga People      Firearms
#
#                     weapsubtype1_txt  nkill  nwound
# 0             Unknown Explosive Type    0.0     0.0
# 1             Unknown Explosive Type    4.0     0.0
# 2             Unknown Explosive Type    0.0     0.0
# 3                   Unknown Gun Type    0.0     0.0
# 4  Automatic or Semi-Automatic Rifle    NaN     NaN

# %%
plt.figure(figsize=(16,7))
sns.heatmap(dataset.isnull(),cmap='viridis',cbar=False)

# %%
dataset.rename(columns={'imonth': 'Month',
 'iyear': 'Year',
 'eventid': 'Event ID',
 'country_txt': 'Country',
 'region_txt': 'Region',
 'provstate': 'State',
 'city': 'City',
 'attacktype1_txt': 'Attack type',
 'targtype1_txt': 'Target',
 'natlty1_txt': 'Nationality',
 'gname': 'Terrorist Group',
 'weaptype1_txt': 'Weapon type',
 'weapsubtype1_txt': 'Weapon subtype',
 'nkill': 'Killed',
 'nwound': 'Wounded'},inplace=True)
# Out:
# C:\Users\Asutosh\Anaconda3\lib\site-packages\pandas\core\frame.py:4025: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   return super(DataFrame, self).rename(**kwargs)

# %%
dataset.head()
# Out:
#        Event ID  Year  Month Country      Region        State        City  \
# 0  197202220004  1972      2   India  South Asia        Delhi   New Delhi
# 1  197501190004  1975      1   India  South Asia        Bihar  Samastipur
# 2  197605260001  1976      5   India  South Asia        Delhi   New Delhi
# 3  197709280004  1977      9   India  South Asia  Maharashtra      Bombay
# 4  197901130004  1979      1   India  South Asia        Assam     Unknown
#
#     latitude  longitude  success        Attack type                Target  \
# 0  28.585836  77.153336        1          Hijacking   Airports & Aircraft
# 1  25.863042  85.781004        1  Bombing/Explosion  Government (General)
# 2  28.585836  77.153336        1  Bombing/Explosion   Airports & Aircraft
# 3  19.075984  72.877656        1          Hijacking   Airports & Aircraft
# 4  26.200605  92.937574        1      Armed Assault                Police
#
#   Nationality          Terrorist Group Weapon type  \
# 0     Germany             Palestinians  Explosives
# 1       India             Ananda Marga  Explosives
# 2       India                  Unknown  Explosives
# 3       Japan  Japanese Red Army (JRA)    Firearms
# 4       India              Naga People    Firearms
#
#                       Weapon subtype  Killed  Wounded
# 0             Unknown Explosive Type     0.0      0.0
# 1             Unknown Explosive Type     4.0      0.0
# 2             Unknown Explosive Type     0.0      0.0
# 3                   Unknown Gun Type     0.0      0.0
# 4  Automatic or Semi-Automatic Rifle     NaN      NaN

# %%
dataset['Weapon subtype'].fillna('No Record',inplace = True)
dataset['Nationality'].fillna('Unknown', inplace = True)
dataset.dropna(inplace = True)
# Out:
# C:\Users\Asutosh\Anaconda3\lib\site-packages\pandas\core\generic.py:6130: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)
# C:\Users\Asutosh\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
dataset['Casualties']=dataset['Killed']+dataset['Wounded']
# Out:
# C:\Users\Asutosh\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
dataset.head()
# Out:
#        Event ID  Year  Month Country      Region        State        City  \
# 0  197202220004  1972      2   India  South Asia        Delhi   New Delhi
# 1  197501190004  1975      1   India  South Asia        Bihar  Samastipur
# 2  197605260001  1976      5   India  South Asia        Delhi   New Delhi
# 3  197709280004  1977      9   India  South Asia  Maharashtra      Bombay
# 5  197901140001  1979      1   India  South Asia      Manipur      Imphal
#
#     latitude  longitude  success        Attack type                Target  \
# 0  28.585836  77.153336        1          Hijacking   Airports & Aircraft
# 1  25.863042  85.781004        1  Bombing/Explosion  Government (General)
# 2  28.585836  77.153336        1  Bombing/Explosion   Airports & Aircraft
# 3  19.075984  72.877656        1          Hijacking   Airports & Aircraft
# 5  24.798346  93.940430        1      Assassination  Government (General)
#
#   Nationality          Terrorist Group Weapon type          Weapon subtype  \
# 0     Germany             Palestinians  Explosives  Unknown Explosive Type
# 1       India             Ananda Marga  Explosives  Unknown Explosive Type
# 2       India                  Unknown  Explosives  Unknown Explosive Type
# 3       Japan  Japanese Red Army (JRA)    Firearms        Unknown Gun Type
# 5       India                  Unknown    Firearms                 Handgun
#
#    Killed  Wounded  Casualties
# 0     0.0      0.0         0.0
# 1     4.0      0.0         4.0
# 2     0.0      0.0         0.0
# 3     0.0      0.0         0.0
# 5     3.0      0.0         3.0

# %%
plt.figure(figsize=(16,7))
sns.heatmap(dataset.isnull(),cmap='viridis',cbar=False)

# %%
#now the data is cleaned
India=dataset

# %%
India.head()
# Out:
#        Event ID  Year  Month Country      Region        State        City  \
# 0  197202220004  1972      2   India  South Asia        Delhi   New Delhi
# 1  197501190004  1975      1   India  South Asia        Bihar  Samastipur
# 2  197605260001  1976      5   India  South Asia        Delhi   New Delhi
# 3  197709280004  1977      9   India  South Asia  Maharashtra      Bombay
# 5  197901140001  1979      1   India  South Asia      Manipur      Imphal
#
#     latitude  longitude  success        Attack type                Target  \
# 0  28.585836  77.153336        1          Hijacking   Airports & Aircraft
# 1  25.863042  85.781004        1  Bombing/Explosion  Government (General)
# 2  28.585836  77.153336        1  Bombing/Explosion   Airports & Aircraft
# 3  19.075984  72.877656        1          Hijacking   Airports & Aircraft
# 5  24.798346  93.940430        1      Assassination  Government (General)
#
#   Nationality          Terrorist Group Weapon type          Weapon subtype  \
# 0     Germany             Palestinians  Explosives  Unknown Explosive Type
# 1       India             Ananda Marga  Explosives  Unknown Explosive Type
# 2       India                  Unknown  Explosives  Unknown Explosive Type
# 3       Japan  Japanese Red Army (JRA)    Firearms        Unknown Gun Type
# 5       India                  Unknown    Firearms                 Handgun
#
#    Killed  Wounded  Casualties
# 0     0.0      0.0         0.0
# 1     4.0      0.0         4.0
# 2     0.0      0.0         0.0
# 3     0.0      0.0         0.0
# 5     3.0      0.0         3.0

# %%
Attacks_count=India.Year.value_counts()

# %%
Attacks_count
# Out:
# 2016    958
# 2017    924
# 2015    833
# 2014    810
# 2013    670
# 2009    663
# 2010    660
# 2011    634
# 2012    586
# 2008    527
# 1990    335
# 1991    328
# 1988    324
# 1989    294
# 2001    226
# 1992    225
# 2003    184
# 1997    175
# 2002    173
# 1995    171
# 2000    166
# 1996    166
# 1987    160
# 2006    150
# 1984    147
# 2007    139
# 2005    137
# 1994    104
# 1999    100
# 1986     94
# 2004     90
# 1998     54
# 1983     39
# 1985     34
# 1979     16
# 1982     13
# 1981     11
# 1980      9
# 1972      1
# 1977      1
# 1975      1
# 1976      1
# Name: Year, dtype: int64

# %%
plt.figure(figsize=(16,9))
plt.xticks(rotation=90)
sns.barplot(Attacks_count.index, Attacks_count.values)

# %%
filter =India[India['Terrorist Group'].isin(India['Terrorist Group'].value_counts()[0:15].index)][['Casualties','Terrorist Group']].groupby('Terrorist Group').sum().reset_index().merge(India[India['Terrorist Group'].isin(India['Terrorist Group'].value_counts()[0:15].index)]['Terrorist Group'].value_counts().to_frame().reset_index().rename(columns={'index':'Terrorist Group','Terrorist Group':'Attacks'}), on='Terrorist Group').sort_values(by='Attacks',ascending=False)

# %%
filter
# Out:
#                                       Terrorist Group  Casualties  Attacks
# 14                                            Unknown     15002.0     4068
# 0      Communist Party of India - Maoist (CPI-Maoist)      3945.0     1821
# 5                                             Maoists      1554.0     1338
# 12                                    Sikh Extremists      4325.0      661
# 13            United Liberation Front of Assam (ULFA)      2727.0      341
# 2                              Hizbul Mujahideen (HM)      1085.0      195
# 4                               Lashkar-e-Taiba (LeT)      2863.0      178
# 8        National Democratic Front of Bodoland (NDFB)       952.0      163
# 1                       Garo National Liberation Army       178.0      151
# 7                                  Muslim Separatists       399.0      117
# 11                           People's War Group (PWG)       503.0       92
# 6                                    Muslim Militants       919.0       86
# 9   National Socialist Council of Nagaland-Isak-Mu...       179.0       86
# 10                   People's Liberation Army (India)       264.0       84
# 3                                 Kashmiri extremists       448.0       77

# %%
filter.plot.barh(x='Terrorist Group',y=['Attacks','Casualties'],figsize=(12,10),stacked=True)

# %%
filter = India[India['State']=='Jammu and Kashmir']['Terrorist Group'].value_counts()[0:10]

# %%
sns.set_context(context='notebook',font_scale=1.5)
plt.figure(figsize=(16,6))
plt.xticks(rotation=90)
sns.barplot(filter.index, filter.values)

# %%
India['State'].value_counts()[0:10].to_frame().plot.bar(figsize=(16,6),width=0.3)
plt.ylabel('Attacks')
# Out:
# Text(0,0.5,'Attacks')

# %%
import plotly
import plotly.plotly as py
import plotly.graph_objs as go

# %%
data = [go.Scattermapbox(
            lat= India['latitude'] ,
            lon= India['longitude'],
            customdata = India['Event ID'],
            mode='markers',
            marker=dict(
                size= 3.5,
                color = 'red',
                opacity = .7,
            ),
          )]
layout = go.Layout(autosize=False,
                   mapbox= dict(accesstoken="pk.eyJ1Ijoic2hhejEzIiwiYSI6ImNqYXA3NjhmeDR4d3Iyd2w5M2phM3E2djQifQ.yyxsAzT94VGYYEEOhxy87w",
                                bearing=0,
                                pitch=50,
                                zoom=4.5,
                                center= dict(
                                         lat=19.5,
                                         lon=80.5),
                                style= "mapbox://styles/mapbox/satellite-v8"),
                    width=900,
                    height=600, title = "Terrorist attack locations in india")

# %%
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot

# %%
init_notebook_mode(connected=True)
# Out:
# <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script><script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window._Plotly) {require(['plotly'],function(plotly) {window._Plotly=plotly;});}</script>

# %%
fig = dict(data=data, layout=layout)
iplot(fig)
# Out:
# <div id="f911a7dd-2df6-4977-b0a3-37809188b4de" style="height: 600px; width: 900px;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
# if (document.getElementById